# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv("imdb movies.csv")

# %%
movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
movies.sort_values('imdb_title_id')
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
min = movies.sort_values(['duration'])

# %%
min
# Out:
#       imdb_title_id                                              title  \
# 32798     tt0142235                  Dragon Ball Z: La vendetta divina
# 57390     tt1365598                                             Enigma
# 3966      tt0033949                                      Niagara Falls
# 54562    tt11443714  My Little Pony: Equestria Girls - Holidays Unw...
# 0         tt0000009                                         Miss Jerry
# ...             ...                                                ...
# 53877     tt1094643             Kagadanan sa banwaan ning mga engkanto
# 54835    tt11617492                                             Orbius
# 39346     tt0270784                     Khleb - imya sushchestvitelnoe
# 38038     tt0246135                             Out 1, noli me tangere
# 85057     tt9047474                                            La flor
#
#                                           original_title  year date_published  \
# ...

# %%
print("Name of the movie with third lowest buget: ",min.iloc[2,5])
# Out:
# Name of the movie with third lowest buget:  Comedy, Romance

# %%
print("Name of the movie with third highest buget: ",min.iloc[3,6])
# Out:
# Name of the movie with third highest buget:  44

# %%
print("Name of the movie with third highest buget: ",min.iloc[54877,5])
# Out:
# Name of the movie with third highest buget:  Thriller

# %%
print("Name of the movie with third highest buget: ",movies.iloc[1,6])
# Out:
# Name of the movie with third highest buget:  70

# %%
print("Name of the movie with third highest buget: ",movies.iloc[3,6])
# Out:
# Name of the movie with third highest buget:  100

# %%
movies["original_title"].max()
# Out:
# 'ärtico'

# %%
max= movies.sort_values(['original_title'])

# %%
max
# Out:
#       imdb_title_id                  title         original_title  year  \
# 17024     tt0073045               "Giliap"               "Giliap"  1975
# 3720      tt0033122   "Swing it" magistern   "Swing it" magistern  1940
# 58171     tt1442481  #73, Shaanthi Nivaasa  #73, Shaanthi Nivaasa  2007
# 81351     tt6856592              #Captured              #Captured  2017
# 82205     tt7272948              #Followme              #Followme  2019
# ...             ...                    ...                    ...   ...
# 50468     tt0827748             Üç sevgili             Üç sevgili  1972
# 36445     tt0208606           Üçüncü Sayfa           Üçüncü Sayfa  1999
# 54109    tt11110904                 Þorsti                 Þorsti  2019
# 72762     tt3823018                Passeri                Þrestir  2015
# 71532     tt3509772                 ärtico                 ärtico  2014
#
#       date_published                   genre  duration  \
# ...

# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv("imdb movies.csv")
# Out:
# C:\Users\kushal\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
print(d['country'])
# Out:
# 0                     USA
# 1               Australia
# 2        Germany, Denmark
# 3                     USA
# 4                   Italy
#                ...
# 85850     France, Belgium
# 85851         Netherlands
# 85852               India
# 85853              Turkey
# 85854               Spain
# Name: country, Length: 85855, dtype: object

# %%
print(d[country:USA])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10628/2007108213.py in <module>
# ----> 1 print(d[country:USA])
#
# NameError: name 'country' is not defined

# %%
d['duration'].values[45]
# Out:
# 65

# %%
d
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
min
# Out:
# <function min>

# %%
print("Name of the movie with third lowest buget: ",d.iloc[2,5])
# Out:
# Name of the movie with third lowest buget:  Drama

# %%
d.iat[2,5] #from starting
# Out:
# 'Drama'

# %%
d.iat[-2,5] #from ending
# Out:
# 'Drama, Family'

# %%
d
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
search='A'
d["country"].str.startswith(search)
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 85850    False
# 85851    False
# 85852    False
# 85853    False
# 85854    False
# Name: country, Length: 85855, dtype: object

# %%
search='A'
d["country"].str.endswith(search)
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 85850    False
# 85851    False
# 85852    False
# 85853    False
# 85854    False
# Name: country, Length: 85855, dtype: object

# %%
max=d.sort_values(['duration'])

# %%
max
# Out:
#       imdb_title_id                                              title  \
# 32798     tt0142235                  Dragon Ball Z: La vendetta divina
# 57390     tt1365598                                             Enigma
# 3966      tt0033949                                      Niagara Falls
# 54562    tt11443714  My Little Pony: Equestria Girls - Holidays Unw...
# 0         tt0000009                                         Miss Jerry
# ...             ...                                                ...
# 53877     tt1094643             Kagadanan sa banwaan ning mga engkanto
# 54835    tt11617492                                             Orbius
# 39346     tt0270784                     Khleb - imya sushchestvitelnoe
# 38038     tt0246135                             Out 1, noli me tangere
# 85057     tt9047474                                            La flor
#
#                                           original_title  year date_published  \
# ...

# %%
d.sort_values(['reviews_from_users'])
# Out:
#       imdb_title_id                       title              original_title  \
# 0         tt0000009                  Miss Jerry                  Miss Jerry
# 58581     tt1484521                    30 Beats                    30 Beats
# 58576     tt1483799                    Sham moh                    Sham moh
# 14085     tt0064628          Mama vyshla zamuzh          Mama vyshla zamuzh
# 14092     tt0064646     Mazel Tov ou le mariage     Mazel Tov ou le mariage
# ...             ...                         ...                         ...
# 85848     tt9905462                   Pengalila                   Pengalila
# 85850     tt9908390                     Le lion                     Le lion
# 85852     tt9911774   Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 85853     tt9914286           Sokagin Çocuklari           Sokagin Çocuklari
# 85854     tt9914942  La vida sense la Sara Amat  La vida sense la Sara Amat
#
#        year date_published            genre  duration  \
# ...

# %%
d["duration"].max()
# Out:
# 808

# %%
d['language'].values[4]
# Out:
# 'Italian'

# %%
d[d['duration'] > 700] #between the values
# Out:
#       imdb_title_id                   title          original_title  year  \
# 38038     tt0246135  Out 1, noli me tangere  Out 1, noli me tangere  1971
# 85057     tt9047474                 La flor                 La flor  2016
#
#       date_published                    genre  duration    country  \
# 38038     2015-11-18           Drama, Mystery       729     France
# 85057     2018-09-21  Drama, Fantasy, Musical       808  Argentina
#
#                                                 language  \
# 38038                                    French, English
# 85057  Catalan, Spanish, French, English, Russian, Ge...
#
#                                  director  ...  \
# 38038  Jacques Rivette, Suzanne Schiffman  ...
# 85057                      Mariano Llinás  ...
#
#                                                   actors  \
# 38038  Michèle Moretti, Hermine Karagheuz, Karen Puig...
# 85057  Elisa Carricajo, Valeria Correa, Pilar Gamboa,...
#
# ...

# %%
pd.DataFrame(d, columns = ['title', 'year', 'budget']) #printing certain columns
# Out:
#                                 title  year   budget
# 0                          Miss Jerry  1894      NaN
# 1         The Story of the Kelly Gang  1906   $ 2250
# 2                      Den sorte drøm  1911      NaN
# 3                           Cleopatra  1912  $ 45000
# 4                           L'Inferno  1911      NaN
# ...                               ...   ...      ...
# 85850                         Le lion  2020      NaN
# 85851  De Beentjes van Sint-Hildegard  2020      NaN
# 85852       Padmavyuhathile Abhimanyu  2019      NaN
# 85853               Sokagin Çocuklari  2019      NaN
# 85854      La vida sense la Sara Amat  2019      NaN
#
# [85855 rows x 3 columns]

# %%
d.shape
# Out:
# (85855, 22)

# %%
d.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
d.country
# Out:
# 0                     USA
# 1               Australia
# 2        Germany, Denmark
# 3                     USA
# 4                   Italy
#                ...
# 85850     France, Belgium
# 85851         Netherlands
# 85852               India
# 85853              Turkey
# 85854               Spain
# Name: country, Length: 85855, dtype: object

# %%
d['country'][0]
# Out:
# 'USA'

# %%
d.iloc[0]
# Out:
# imdb_title_id                                                    tt0000009
# title                                                           Miss Jerry
# original_title                                                  Miss Jerry
# year                                                                  1894
# date_published                                                  1894-10-09
# genre                                                              Romance
# duration                                                                45
# country                                                                USA
# language                                                              None
# director                                                   Alexander Black
# writer                                                     Alexander Black
# production_company                              Alexander Black Photoplays
# ...

# %%
d.iloc[:, 0]
# Out:
# 0        tt0000009
# 1        tt0000574
# 2        tt0001892
# 3        tt0002101
# 4        tt0002130
#            ...
# 85850    tt9908390
# 85851    tt9911196
# 85852    tt9911774
# 85853    tt9914286
# 85854    tt9914942
# Name: imdb_title_id, Length: 85855, dtype: object

# %%
d.iloc[1:3, 0]
# Out:
# 1    tt0000574
# 2    tt0001892
# Name: imdb_title_id, dtype: object

# %%
d.loc[0, 'country']
# Out:
# 'USA'

# %%
d.country == 'Italy'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 85850    False
# 85851    False
# 85852    False
# 85853    False
# 85854    False
# Name: country, Length: 85855, dtype: bool

# %%
d.loc[d.country == 'Italy']
# Out:
#       imdb_title_id                             title  \
# 4         tt0002130                         L'Inferno
# 7         tt0002445                        Quo Vadis?
# 14        tt0003102        Ma l'amor mio non muore...
# 20        tt0003489       Gli ultimi giorni di Pompei
# 21        tt0003637                     Assunta Spina
# ...             ...                               ...
# 85615     tt9625240                             Nevia
# 85632     tt9639274                            Bangla
# 85739     tt9778888       Il sindaco del Rione Sanità
# 85796     tt9840382                   Se mi vuoi bene
# 85819     tt9872556  Momenti di trascurabile felicità
#
#                          original_title  year date_published  \
# 4                             L'Inferno  1911     1911-03-06
# 7                            Quo Vadis?  1913     1913-03-01
# 14           Ma l'amor mio non muore...  1914     1914-01-01
# 20          Gli ultimi giorni di Pompei  1913     1913-08-24
# ...

# %%
d.title.describe()
# Out:
# count     85855
# unique    82094
# top        Anna
# freq         10
# Name: title, dtype: object

# %%
d.head(1)
# Out:
#   imdb_title_id       title original_title  year date_published    genre  \
# 0     tt0000009  Miss Jerry     Miss Jerry  1894     1894-10-09  Romance
#
#    duration country language         director  ...  \
# 0        45     USA     None  Alexander Black  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
#
#                                          description avg_vote votes  budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154     NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
#
#    reviews_from_critics
# 0                   2.0
#
# [1 rows x 22 columns]

# %%
d.sort_values(by='country', ascending=False)
# Out:
#       imdb_title_id                           title  \
# 83540     tt7981318                        Cook Off
# 20419     tt0084033                  Gräset sjunger
# 15284     tt0067958      W.R. - Misterije organizma
# 19893     tt0082356                      Il Falcone
# 31739     tt0125212  I Bog stvori kafansku pevacicu
# ...             ...                             ...
# 85204     tt9161168                 Kindred Spirits
# 85320     tt9261042                  A Perfect Plan
# 85492     tt9466848                          Kedara
# 85608     tt9617578            It Started as a Joke
# 85845     tt9904250        La reina de los lagartos
#
#                        original_title  year date_published  \
# 83540                        Cook Off  2017     2017-12-01
# 20419                  Gräset sjunger  1981     1982-09-10
# 15284      W.R. - Misterije organizma  1971     1971-05-10
# 19893               Banovic Strahinja  1981     1983-03-30
# ...

# %%
d[pd.isnull(d.country)]
# Out:
#       imdb_title_id                                  title  \
# 53010    tt10452854                               The 24th
# 53112    tt10514532                        Into the Forest
# 53117    tt10516176                           Steel Rain 2
# 53228    tt10582422                         Sweet Sunshine
# 53528    tt10764458  Friends: The One with the Anniversary
# ...             ...                                    ...
# 85204     tt9161168                        Kindred Spirits
# 85320     tt9261042                         A Perfect Plan
# 85492     tt9466848                                 Kedara
# 85608     tt9617578                   It Started as a Joke
# 85845     tt9904250               La reina de los lagartos
#
#                               original_title  year date_published  \
# 53010                               The 24th  2020     2020-08-21
# 53112                        Into the Forest  2019     2019-06-22
# ...

# %%
d.country.fillna("Unknown")
# Out:
# 0                     USA
# 1               Australia
# 2        Germany, Denmark
# 3                     USA
# 4                   Italy
#                ...
# 85850     France, Belgium
# 85851         Netherlands
# 85852               India
# 85853              Turkey
# 85854               Spain
# Name: country, Length: 85855, dtype: object

# %%
d[pd.isnull(d.country)]
# Out:
#       imdb_title_id                                  title  \
# 53010    tt10452854                               The 24th
# 53112    tt10514532                        Into the Forest
# 53117    tt10516176                           Steel Rain 2
# 53228    tt10582422                         Sweet Sunshine
# 53528    tt10764458  Friends: The One with the Anniversary
# ...             ...                                    ...
# 85204     tt9161168                        Kindred Spirits
# 85320     tt9261042                         A Perfect Plan
# 85492     tt9466848                                 Kedara
# 85608     tt9617578                   It Started as a Joke
# 85845     tt9904250               La reina de los lagartos
#
#                               original_title  year date_published  \
# 53010                               The 24th  2020     2020-08-21
# 53112                        Into the Forest  2019     2019-06-22
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("imdb movies.csv")
# Out:
# C:\Users\kushal\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
y=d.duration

# %%
y
# Out:
# 0         45
# 1         70
# 2         53
# 3        100
# 4         68
#         ...
# 85850     95
# 85851    103
# 85852    130
# 85853     98
# 85854     74
# Name: duration, Length: 85855, dtype: int64

# %%
plt.pie(y)
plt.show()

# %%
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("imdb movies.csv")
# Out:
# C:\Users\kushal\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
y=d.duration

# %%
y
# Out:
# 0         45
# 1         70
# 2         53
# 3        100
# 4         68
#         ...
# 85850     95
# 85851    103
# 85852    130
# 85853     98
# 85854     74
# Name: duration, Length: 85855, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("imdb movies.csv")
# Out:
# C:\Users\kushal\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
y=d.duration

# %%
y
# Out:
# 0         45
# 1         70
# 2         53
# 3        100
# 4         68
#         ...
# 85850     95
# 85851    103
# 85852    130
# 85853     98
# 85854     74
# Name: duration, Length: 85855, dtype: int64

# %%
plt.pie(y)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv("imdb movies.csv")
# Out:
# C:\Users\kushal\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
d[d.country == 'USA']
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000009                                         Miss Jerry
# 3         tt0002101                                          Cleopatra
# 5         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17        tt0003167                                     Amore di madre
# 19        tt0003471                                   Traffic in Souls
# ...             ...                                                ...
# 85829     tt9887520                                     Season of Love
# 85830     tt9887580                                      Bulletproof 2
# 85837     tt9894470                                                VFW
# 85838     tt9896916                             The Pilgrim's Progress
# 85839     tt9898858                                    Coffee & Kareem
#
#                                           original_title  year date_published  \
# ...

# %%
d[d['genre'].str.contains('Comedy')]
# Out:
#       imdb_title_id                                      title  \
# 28        tt0003973                      A Florida Enchantment
# 39        tt0004707                 Tillie's Punctured Romance
# 43        tt0004825  The Wishing Ring: An Idyll of Old England
# 62        tt0006327                              Young Romance
# 67        tt0006617                                 Dödskyssen
# ...             ...                                        ...
# 85839     tt9898858                            Coffee & Kareem
# 85841     tt9899880                                   Columbus
# 85849     tt9906644                                  Manoharam
# 85850     tt9908390                                    Le lion
# 85851     tt9911196             De Beentjes van Sint-Hildegard
#
#                                   original_title  year date_published  \
# 28                         A Florida Enchantment  1914     1916-09-04
# ...

# %%
d.groupby('title').mean()
# Out:
#                        duration  avg_vote   votes  metascore  \
# title
# "Giliap"                  137.0      6.50   739.0        NaN
# "Swing it" magistern       92.0      6.10   238.0        NaN
# #73, Shaanthi Nivaasa     157.0      7.10   178.0        NaN
# #Captured                  81.0      5.00   741.0        NaN
# #Followme                  90.0      3.50   415.0        NaN
# ...                         ...       ...     ...        ...
# Üç arkadas                 87.0      6.95   305.5        NaN
# Üç sevgili                 77.0      5.70   158.0        NaN
# Üçüncü Sayfa               92.0      7.40  3101.0        NaN
# Þorsti                     90.0      6.80   186.0        NaN
# ärtico                     78.0      5.90   107.0        NaN
#
#                        reviews_from_users  reviews_from_critics
# title
# "Giliap"                              5.0                   6.0
# "Swing it" magistern                  3.0                   NaN
# ...

# %%
d
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
d.groupby('duration').min()
# Out:
# C:\Users\kushal\AppData\Local\Temp/ipykernel_19112/3106061289.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   z= d.groupby('duration').min()

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("fico.csv")

# %%
df
# Out:
#         acct_id FICO
# 0             1  768
# 1             2  850
# 2             3  677
# 3             4  843
# 4             5  796
# ...         ...  ...
# 100008    99996  NaN
# 100009    99997  NaN
# 100010    99998  NaN
# 100011    99999  SSS
# 100012   100000  NaN
#
# [100013 rows x 2 columns]

# %%
df.isnull()
# Out:
#         acct_id   FICO
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ...         ...    ...
# 100008    False   True
# 100009    False   True
# 100010    False   True
# 100011    False  False
# 100012    False   True
#
# [100013 rows x 2 columns]

# %%
df1 = df["FICO"].replace(np.nan, "Missing")

# %%
df1
# Out:
# 0             768
# 1             850
# 2             677
# 3             843
# 4             796
#            ...
# 100008    Missing
# 100009    Missing
# 100010    Missing
# 100011        SSS
# 100012    Missing
# Name: FICO, Length: 100013, dtype: object

# %%
hist=df.hist()

# %%
x=df.iloc[:,0]

# %%
x
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 100008     99996
# 100009     99997
# 100010     99998
# 100011     99999
# 100012    100000
# Name: acct_id, Length: 100013, dtype: int64

# %%
x.hist()
# Out:
# <AxesSubplot:>

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0         768
# 1         850
# 2         677
# 3         843
# 4         796
#          ...
# 100008    NaN
# 100009    NaN
# 100010    NaN
# 100011    SSS
# 100012    NaN
# Name: FICO, Length: 100013, dtype: object

# %%
y.hist()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x="FICO",y="acct_id",data=df)
plt.xticks(
    rotation=90, 
    horizontalalignment='right'
)

plt.gcf().set_size_inches(20, 9)

# %%
sns.violinplot(x="FICO",y="acct_id",data=df)
plt.xticks(
    rotation=90, 
    horizontalalignment='right'
)

plt.gcf().set_size_inches(20, 9)
